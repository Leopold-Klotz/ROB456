# %%
# Initialize Otter
import otter
grader = otter.Notebook("check_kalman_filter.ipynb")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\leopo\My Drive\Fall 2023\Robotics\ROB456\RobotHallway\check_kalman_filter.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/leopo/My%20Drive/Fall%202023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # Initialize Otter
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leopo/My%20Drive/Fall%202023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> import otter
#       <a href='vscode-notebook-cell:/c%3A/Users/leopo/My%20Drive/Fall%202023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> grader = otter.Notebook("check_kalman_filter.ipynb")
#
# ModuleNotFoundError: No module named 'otter'

# %% [markdown]
# # Kalman filter
#
# This Jupyter notebook file imports (and tests) all of the code needed to do the Kalman' filter assignment. Note that the actual code is in the .py files in this directory.
#
# This is where you'll fill in the missing code from the last assignment
#
# Slides for this assignment: https://docs.google.com/presentation/d/1Q6w-vczvWHanGDqbuz6H1qhTOkSrX54kf1g8NgTcipQ/edit?usp=sharing

# %% [markdown]
# ## Robot ground truth
# This gets all the code in Robot_ground_truth.py. If you change any code in that file then you will need to re-execute this import.

# %%
import sys; sys.path.insert(0, '.')

# These commands will force JN to actually re-load the external file when you re-execute the import command
# %load_ext autoreload
# %autoreload 2

# %%
from robot_ground_truth import RobotGroundTruth, test_continuous_move_functions

# %%
# Syntax check
robot_gt = RobotGroundTruth()
robot_gt.reset_location()
robot_gt.set_move_continuos_probabilities(0.01)
ret_amt_moved = robot_gt.move_continuous(0.0)
if -0.1 < ret_amt_moved < 0.1:
    print(f"Robot ground truth: Passed move continuous syntax check")
# Out:
# Robot ground truth: Passed move continuous syntax check

# %%
# Edit the code in robot_ground_truth.py (the methods tagged with Kalman assignment)
test_continuous_move_functions()
# Out:
# Checking move with normal distribution probabilities
# Passed continuous tests
# True

# %%
grader.check("robotGT")
# Out:
# robotGT results:
#     robotGT - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert(test_continuous_move_functions(b_print=False))
#         Expecting nothing
#         **********************************************************************
#         Line 1, in robotGT 0
#         Failed example:
#             assert(test_continuous_move_functions(b_print=False))
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest robotGT 0[0]>", line 1, in <module>
#                 assert(test_continuous_move_functions(b_print=False))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#             NameError: name 'test_continuous_move_functions' is not defined

# %% [markdown]
# ## Robot sensors

# %%
from robot_sensors import RobotSensors, test_continuous_sensor

# %%
# Syntax check
robot_gt = RobotGroundTruth()
robot_sensor = RobotSensors()
robot_sensor.set_distance_wall_sensor_probabilities(sigma=0.01)
dist_with_noise = robot_sensor.query_distance_to_wall(robot_gt)
if 0.0 < dist_with_noise < 1.0:
    print("Dist wall sensor, passed syntax test")
# Out:
# Dist wall sensor, passed syntax test

# %%
# Edit the code in robot_sensors.py (the methods tagged with Bayes assignment)
test_continuous_sensor()
# Out:
# Checking query wall with normal distribution probabilities
# Passed continuous tests
# True

# %%
grader.check("robot_sensors")
# Out:
# robot_sensors results:
#     robot_sensors - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert(test_continuous_sensor(b_print=False))
#         Expecting nothing
#         **********************************************************************
#         Line 1, in robot_sensors 0
#         Failed example:
#             assert(test_continuous_sensor(b_print=False))
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest robot_sensors 0[0]>", line 1, in <module>
#                 assert(test_continuous_sensor(b_print=False))
#                        ^^^^^^^^^^^^^^^^^^^^^^
#             NameError: name 'test_continuous_sensor' is not defined

# %% [markdown]
# ## Kalman filter
#
# This is the part where you actually *do* the kalman filter update. There's two parts, the sensor update and the move update. The test file runs a sensor, then a move, then a sequence of sensor, sequence of move, then a mix.

# %%
from kalman_filter import KalmanFilter, test_kalman_update

# %%
# Syntax checks
kalman_filter = KalmanFilter()
robot_ground_truth = RobotGroundTruth()
robot_sensor = RobotSensors()

# Set mu/sigmas
sensor_noise = {"mu": 0.0, "sigma": 0.1}
move_error = {"mu": 0.0, "sigma": 0.05}
robot_ground_truth.set_move_continuos_probabilities(move_error["sigma"])
robot_sensor.set_distance_wall_sensor_probabilities(sensor_noise["sigma"])

kalman_filter.update_belief_distance_sensor(robot_sensor, 0.1)
kalman_filter.update_continuous_move(robot_ground_truth, 0.0)
# Out:
# (0.17999999999999994, 0.13)

# %%
test_kalman_update()
# Out:
# Testing Kalman
# Passed
# True

# %%
grader.check("kalman_filter")
# Out:
# kalman_filter results:
#     kalman_filter - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert(test_kalman_update(b_print=False))
#         Expecting nothing
#         **********************************************************************
#         Line 1, in kalman_filter 0
#         Failed example:
#             assert(test_kalman_update(b_print=False))
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest kalman_filter 0[0]>", line 1, in <module>
#                 assert(test_kalman_update(b_print=False))
#                        ^^^^^^^^^^^^^^^^^^
#             NameError: name 'test_kalman_update' is not defined

# %% [markdown]
# ## Hours and collaborators
# Required for every assignment - fill out before you hand-in.
#
# Listing names and websites helps you to document who you worked with and what internet help you received in the case of any plagiarism issues. You should list names of anyone (in class or not) who has substantially helped you with an assignment - or anyone you have *helped*. You do not need to list TAs.
#
# Listing hours helps us track if the assignments are too long.

# %%
# List of names (creates a set)
worked_with_names = {"Only TA"}
# List of URLS (creates a set)
websites = {"https://medium.com/@jaems33/understanding-kalman-filters-with-python-2310e87b8f48"}
# Approximate number of hours, including lab/in-class time
hours = 3

# for all row, column in all_indices_from_where
#.   if this is the column for wrist torque 
#.      print(f"Row: {r}, Time step: {c // n_time_steps} Successful y/n: {pick_data[r, -1] == 1}, value: {pick_data[r, c]}")

# %%
grader.check("hours_collaborators")
# Out:
# hours_collaborators results:
#     hours_collaborators - 1 result:
#         ❌ Test case failed
#         Trying:
#             assert(not "not filled out" in worked_with_names)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in hours_collaborators 0
#         Failed example:
#             assert(not "not filled out" in worked_with_names)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest hours_collaborators 0[0]>", line 1, in <module>
#                 assert(not "not filled out" in worked_with_names)
#                                                ^^^^^^^^^^^^^^^^^
#             NameError: name 'worked_with_names' is not defined
#
#     hours_collaborators - 2 result:
#         ❌ Test case failed
#         Trying:
#             assert(not "not filled out" in websites)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in hours_collaborators 1
#         Failed example:
#             assert(not "not filled out" in websites)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest hours_collaborators 1[0]>", line 1, in <module>
#                 assert(not "not filled out" in websites)
#                                                ^^^^^^^^
#             NameError: name 'websites' is not defined
#
#     hours_collaborators - 3 result:
#         ❌ Test case failed
#         Trying:
#             assert(hours > 0)
#         Expecting nothing
#         **********************************************************************
#         Line 1, in hours_collaborators 2
#         Failed example:
#             assert(hours > 0)
#         Exception raised:
#             Traceback (most recent call last):
#               File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/doctest.py", line 1357, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest hours_collaborators 2[0]>", line 1, in <module>
#                 assert(hours > 0)
#                        ^^^^^
#             NameError: name 'hours' is not defined

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Submit through gradescope, kalman filter. Include JUST this .ipynb file and ALL of the .py files in the RobotHallway folder

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/leo_k/My Drive/Fall 2023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell:/Users/leo_k/My%20Drive/Fall%202023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Save your notebook first, then run this cell to export your submission.
# ----> <a href='vscode-notebook-cell:/Users/leo_k/My%20Drive/Fall%202023/Robotics/ROB456/RobotHallway/check_kalman_filter.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> grader.export(run_tests=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/wrapt/wrappers.py:669, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     666         wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     667         return self._self_wrapper(wrapped, instance, args, kwargs)
# --> 669     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     670             args, kwargs)
#     672 else:
#     673     # As in this case we would be dealing with a classmethod or
#     674     # staticmethod, then _self_instance will only tell us whether
#    (...)
#     683     # class type, as it reflects what they have available in the
#     684     # decoratored function.
#     686     instance = getattr(self.__wrapped__, '__self__', None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/check/utils.py:184, in grading_mode_disabled(wrapped, self, args, kwargs)
#     182 if type(self)._grading_mode:
#     183     return
# --> 184 return wrapped(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/wrapt/wrappers.py:669, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     666         wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     667         return self._self_wrapper(wrapped, instance, args, kwargs)
# --> 669     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     670             args, kwargs)
#     672 else:
#     673     # As in this case we would be dealing with a classmethod or
#     674     # staticmethod, then _self_instance will only tell us whether
#    (...)
#     683     # class type, as it reflects what they have available in the
#     684     # decoratored function.
#     686     instance = getattr(self.__wrapped__, '__self__', None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/check/utils.py:166, in incompatible_with.<locals>.incompatible(wrapped, self, args, kwargs)
#     164     else:
#     165         return
# --> 166 return wrapped(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/wrapt/wrappers.py:669, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     666         wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     667         return self._self_wrapper(wrapped, instance, args, kwargs)
# --> 669     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     670             args, kwargs)
#     672 else:
#     673     # As in this case we would be dealing with a classmethod or
#     674     # staticmethod, then _self_instance will only tell us whether
#    (...)
#     683     # class type, as it reflects what they have available in the
#     684     # decoratored function.
#     686     instance = getattr(self.__wrapped__, '__self__', None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/check/utils.py:217, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     215 except Exception as e:
#     216     self._log_event(event_type, success=False, error=e)
# --> 217     raise e
#     219 if ret is None:
#     220     ret = LoggedEventReturnValue(None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/check/utils.py:213, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     208 """
#     209 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     210 of the wrapped function.
#     211 """
#     212 try:
# --> 213     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     215 except Exception as e:
#     216     self._log_event(event_type, success=False, error=e)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/check/notebook.py:462, in Notebook.export(self, nb_path, export_path, pdf, filtering, pagebreaks, files, display_link, force_save, run_tests)
#     460 pdf_created = True
#     461 if pdf:
# --> 462     pdf_path = export_notebook(nb_path, filtering=filtering, pagebreaks=pagebreaks)
#     463     if os.path.isfile(pdf_path):
#     464         pdf_created = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/export/__init__.py:28, in export_notebook(nb_path, dest, exporter_type, **kwargs)
#      25 except:
#      26     raise ImportError("nbconvert is required for Otter Export but it could not be found")
# ---> 28 from .exporters import get_exporter
#      30 if dest is not None:
#      31     pdf_name = dest
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/export/exporters/__init__.py:5
#       1 """Exporters for Otter Export"""
#       3 import shutil
# ----> 5 from .via_latex import PDFViaLatexExporter
#       7 from ..utils import WkhtmltopdfNotFoundError
#      10 def get_exporter(exporter_type=None):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/export/exporters/via_latex.py:9
#       5 import warnings
#       7 from textwrap import indent
# ----> 9 from .base_exporter import BaseExporter, ExportFailedException, NBCONVERT_6, TEMPLATE_DIR
#      11 from ...utils import print_full_width
#      14 class PDFViaLatexExporter(BaseExporter):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/otter/export/exporters/base_exporter.py:5
#       3 import nbformat
#       4 import nbconvert
# ----> 5 import pkg_resources
#       7 from abc import ABC, abstractmethod
#       9 from .utils import has_begin, has_end, sub_end_for_new_page
#
# ModuleNotFoundError: No module named 'pkg_resources'
